# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("indian_property_dataset.csv")
df
# Out:
#       Property_ID           City            Locality  Area_sqft  Bedrooms  \
# 0       PROP00001  Greater Noida             Alpha 1        552         3
# 1       PROP00002          Delhi           Janakpuri       3309         4
# 2       PROP00003  Greater Noida             Alpha 1        637         2
# 3       PROP00004       Gurugram          Sohna Road       1349         3
# 4       PROP00005          Noida          Sector 137       2537         4
# ...           ...            ...                 ...        ...       ...
# 30295   PROP14088      Faridabad           Sector 15       2694         3
# 30296   PROP09681          Noida           Sector 50       2058         4
# 30297   PROP17797      Faridabad           Sector 15       2239         5
# 30298   PROP28255      Ghaziabad  Crossings Republik       1269         2
# 30299   PROP15765          Delhi           Janakpuri       3577         4
#
#        Bathrooms  Balconies Parking  Floor  Total_Floors  ...  Security  Gym  \
# 0              2          1     Yes     23            24  ...       Yes   No
# 1              4          2     Yes      6            17  ...       Yes   No
# 2              2          0     Yes      3            16  ...        No  Yes
# 3              2          1     Yes     25            28  ...       Yes   No
# 4              3          0     Yes      4            25  ...        No  Yes
# ...          ...        ...     ...    ...           ...  ...       ...  ...
# 30295          3          1     Yes     16            30  ...        No  Yes
# 30296          4          2     Yes     17            21  ...        No   No
# 30297          5          2     Yes     13            19  ...        No   No
# 30298          1          2      No      8            28  ...       Yes   No
# 30299          4          0      No      1            21  ...        No   No
#
#       Swimming_Pool Metro_Distance_km Hospital_Distance_km School_Distance_km  \
# 0               Yes              2.87                 4.90               3.46
# 1                No              6.48                 7.79               2.40
# 2                No              8.45                 5.53               0.61
# 3               Yes              1.80                 1.29               4.52
# 4                No             11.66                 6.91               0.27
# ...             ...               ...                  ...                ...
# 30295            No              5.71                 3.54               0.50
# 30296           Yes              7.10                 5.06               3.83
# 30297           Yes              1.08                 2.20               1.53
# 30298            No              2.13                 7.59               4.41
# 30299            No             11.46                 5.98               0.97
#
#       Mall_Distance_km Expressway_Distance_km RRTS_Distance_km   Price_INR
# 0                 7.30                  10.58             8.68   6605816.0
# 1                 5.74                  12.48            12.56  50590083.0
# 2                 6.53                   8.11             5.27   7060957.0
# 3                 5.62                  11.26             8.85  21786168.0
# 4                 7.35                  10.29            10.97  25215744.0
# ...                ...                    ...              ...         ...
# 30295             8.64                   1.52            10.46  13712757.0
# 30296             9.67                   7.39             8.58  23150309.0
# 30297             3.77                   9.17            14.96  22488862.0
# 30298             9.82                   7.65            12.38  12679497.0
# 30299             5.77                   3.56             4.97  53270189.0
#
# [30300 rows x 26 columns]

# %%
df.head(2)
# Out:
#   Property_ID           City   Locality  Area_sqft  Bedrooms  Bathrooms  \
# 0   PROP00001  Greater Noida    Alpha 1        552         3          2
# 1   PROP00002          Delhi  Janakpuri       3309         4          4
#
#    Balconies Parking  Floor  Total_Floors  ...  Security Gym Swimming_Pool  \
# 0          1     Yes     23            24  ...       Yes  No           Yes
# 1          2     Yes      6            17  ...       Yes  No            No
#
#   Metro_Distance_km Hospital_Distance_km School_Distance_km Mall_Distance_km  \
# 0              2.87                 4.90               3.46             7.30
# 1              6.48                 7.79               2.40             5.74
#
#   Expressway_Distance_km RRTS_Distance_km   Price_INR
# 0                  10.58             8.68   6605816.0
# 1                  12.48            12.56  50590083.0
#
# [2 rows x 26 columns]

# %%
df.tail(2)
# Out:
#       Property_ID       City            Locality  Area_sqft  Bedrooms  \
# 30298   PROP28255  Ghaziabad  Crossings Republik       1269         2
# 30299   PROP15765      Delhi           Janakpuri       3577         4
#
#        Bathrooms  Balconies Parking  Floor  Total_Floors  ...  Security Gym  \
# 30298          1          2      No      8            28  ...       Yes  No
# 30299          4          0      No      1            21  ...        No  No
#
#       Swimming_Pool Metro_Distance_km Hospital_Distance_km School_Distance_km  \
# 30298            No              2.13                 7.59               4.41
# 30299            No             11.46                 5.98               0.97
#
#       Mall_Distance_km Expressway_Distance_km RRTS_Distance_km   Price_INR
# 30298             9.82                   7.65            12.38  12679497.0
# 30299             5.77                   3.56             4.97  53270189.0
#
# [2 rows x 26 columns]

# %%
df.shape
# Out:
# (30300, 26)

# %%
df.describe()
# Out:
#           Area_sqft      Bedrooms     Bathrooms     Balconies         Floor  \
# count  30300.000000  30300.000000  30300.000000  30300.000000  30300.000000
# mean    2466.704686      2.999901      2.705116      1.493927     12.524554
# std     1170.861208      1.411235      1.259312      1.114725      7.523168
# min      450.000000      1.000000      1.000000      0.000000      0.000000
# 25%     1460.000000      2.000000      2.000000      0.000000      6.000000
# 50%     2456.000000      3.000000      3.000000      1.000000     13.000000
# 75%     3483.000000      4.000000      4.000000      2.000000     19.000000
# max     4500.000000      5.000000      5.000000      3.000000     25.000000
#
#        Total_Floors  Property_Age  Metro_Distance_km  Hospital_Distance_km  \
# count  30300.000000  30300.000000       29690.000000          30300.000000
# mean      21.774587     12.480396           6.013805              4.118685
# std        6.684466      7.495824           3.444635              2.238173
# min        1.000000      0.000000           0.100000              0.200000
# 25%       18.000000      6.000000           3.010000              2.190000
# 50%       23.000000     13.000000           6.000000              4.140000
# 75%       27.000000     19.000000           9.000000              6.040000
# max       30.000000     25.000000          12.000000              8.000000
#
#        School_Distance_km  Mall_Distance_km  Expressway_Distance_km  \
# count        30300.000000      30300.000000            30300.000000
# mean             3.099146          5.254310                7.599268
# std              1.679410          2.752919                4.273594
# min              0.200000          0.500000                0.200000
# 25%              1.640000          2.870000                3.920000
# 50%              3.100000          5.260000                7.640000
# 75%              4.560000          7.650000               11.320000
# max              6.000000         10.000000               15.000000
#
#        RRTS_Distance_km     Price_INR
# count      30300.000000  2.969000e+04
# mean          10.314685  2.525635e+07
# std            5.629298  1.456723e+07
# min            0.500000  1.995048e+06
# 25%            5.480000  1.391879e+07
# 50%           10.320000  2.266030e+07
# 75%           15.210000  3.331306e+07
# max           20.000000  8.078048e+07

# %%
df.isnull().sum()
# Out:
# Property_ID                 0
# City                        0
# Locality                    0
# Area_sqft                   0
# Bedrooms                    0
# Bathrooms                   0
# Balconies                   0
# Parking                   610
# Floor                       0
# Total_Floors                0
# Property_Age                0
# Furnishing                  0
# Facing                      0
# Gated_Society               0
# Lift                        0
# Power_Backup                0
# Security                    0
# Gym                       610
# Swimming_Pool               0
# Metro_Distance_km         610
# Hospital_Distance_km        0
# School_Distance_km          0
# Mall_Distance_km            0
# Expressway_Distance_km      0
# RRTS_Distance_km            0
# Price_INR                 610
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(300)

# %%
df["Bedrooms"].mean()
# Out:
# np.float64(2.99990099009901)

# %%
df["Area_sqft"].mean()
# Out:
# np.float64(2466.7046864686467)

# %%
df["Price_INR"].max()
# Out:
# np.float64(80780483.0)

# %%
df["Price_INR"].std()
# Out:
# np.float64(14567229.97800602)

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# Property_ID                 0
# City                        0
# Locality                    0
# Area_sqft                   0
# Bedrooms                    0
# Bathrooms                   0
# Balconies                   0
# Parking                   610
# Floor                       0
# Total_Floors                0
# Property_Age                0
# Furnishing                  0
# Facing                      0
# Gated_Society               0
# Lift                        0
# Power_Backup                0
# Security                    0
# Gym                       610
# Swimming_Pool               0
# Metro_Distance_km         610
# Hospital_Distance_km        0
# School_Distance_km          0
# Mall_Distance_km            0
# Expressway_Distance_km      0
# RRTS_Distance_km            0
# Price_INR                 610
# dtype: int64

# %%
df = df.dropna().reset_index(drop=True)

# %%
df
# Out:
#       Property_ID           City            Locality  Area_sqft  Bedrooms  \
# 0       PROP00001  Greater Noida             Alpha 1        552         3
# 1       PROP00002          Delhi           Janakpuri       3309         4
# 2       PROP00003  Greater Noida             Alpha 1        637         2
# 3       PROP00004       Gurugram          Sohna Road       1349         3
# 4       PROP00005          Noida          Sector 137       2537         4
# ...           ...            ...                 ...        ...       ...
# 29685   PROP14088      Faridabad           Sector 15       2694         3
# 29686   PROP09681          Noida           Sector 50       2058         4
# 29687   PROP17797      Faridabad           Sector 15       2239         5
# 29688   PROP28255      Ghaziabad  Crossings Republik       1269         2
# 29689   PROP15765          Delhi           Janakpuri       3577         4
#
#        Bathrooms  Balconies Parking  Floor  Total_Floors  ...  Security  Gym  \
# 0              2          1     Yes     23            24  ...       Yes   No
# 1              4          2     Yes      6            17  ...       Yes   No
# 2              2          0     Yes      3            16  ...        No  Yes
# 3              2          1     Yes     25            28  ...       Yes   No
# 4              3          0     Yes      4            25  ...        No  Yes
# ...          ...        ...     ...    ...           ...  ...       ...  ...
# 29685          3          1     Yes     16            30  ...        No  Yes
# 29686          4          2     Yes     17            21  ...        No   No
# 29687          5          2     Yes     13            19  ...        No   No
# 29688          1          2      No      8            28  ...       Yes   No
# 29689          4          0      No      1            21  ...        No   No
#
#       Swimming_Pool Metro_Distance_km Hospital_Distance_km School_Distance_km  \
# 0               Yes              2.87                 4.90               3.46
# 1                No              6.48                 7.79               2.40
# 2                No              8.45                 5.53               0.61
# 3               Yes              1.80                 1.29               4.52
# 4                No             11.66                 6.91               0.27
# ...             ...               ...                  ...                ...
# 29685            No              5.71                 3.54               0.50
# 29686           Yes              7.10                 5.06               3.83
# 29687           Yes              1.08                 2.20               1.53
# 29688            No              2.13                 7.59               4.41
# 29689            No             11.46                 5.98               0.97
#
#       Mall_Distance_km Expressway_Distance_km RRTS_Distance_km   Price_INR
# 0                 7.30                  10.58             8.68   6605816.0
# 1                 5.74                  12.48            12.56  50590083.0
# 2                 6.53                   8.11             5.27   7060957.0
# 3                 5.62                  11.26             8.85  21786168.0
# 4                 7.35                  10.29            10.97  25215744.0
# ...                ...                    ...              ...         ...
# 29685             8.64                   1.52            10.46  13712757.0
# 29686             9.67                   7.39             8.58  23150309.0
# 29687             3.77                   9.17            14.96  22488862.0
# 29688             9.82                   7.65            12.38  12679497.0
# 29689             5.77                   3.56             4.97  53270189.0
#
# [29690 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# Property_ID               0
# City                      0
# Locality                  0
# Area_sqft                 0
# Bedrooms                  0
# Bathrooms                 0
# Balconies                 0
# Parking                   0
# Floor                     0
# Total_Floors              0
# Property_Age              0
# Furnishing                0
# Facing                    0
# Gated_Society             0
# Lift                      0
# Power_Backup              0
# Security                  0
# Gym                       0
# Swimming_Pool             0
# Metro_Distance_km         0
# Hospital_Distance_km      0
# School_Distance_km        0
# Mall_Distance_km          0
# Expressway_Distance_km    0
# RRTS_Distance_km          0
# Price_INR                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Property_ID', 'City', 'Locality', 'Area_sqft', 'Bedrooms', 'Bathrooms',
#        'Balconies', 'Parking', 'Floor', 'Total_Floors', 'Property_Age',
#        'Furnishing', 'Facing', 'Gated_Society', 'Lift', 'Power_Backup',
#        'Security', 'Gym', 'Swimming_Pool', 'Metro_Distance_km',
#        'Hospital_Distance_km', 'School_Distance_km', 'Mall_Distance_km',
#        'Expressway_Distance_km', 'RRTS_Distance_km', 'Price_INR'],
#       dtype='str')

# %%
df.drop(columns="Property_ID",inplace=True)

# %%
df.columns
# Out:
# Index(['City', 'Locality', 'Area_sqft', 'Bedrooms', 'Bathrooms', 'Balconies',
#        'Parking', 'Floor', 'Total_Floors', 'Property_Age', 'Furnishing',
#        'Facing', 'Gated_Society', 'Lift', 'Power_Backup', 'Security', 'Gym',
#        'Swimming_Pool', 'Metro_Distance_km', 'Hospital_Distance_km',
#        'School_Distance_km', 'Mall_Distance_km', 'Expressway_Distance_km',
#        'RRTS_Distance_km', 'Price_INR'],
#       dtype='str')

# %%
df.dtypes
# Out:
# City                          str
# Locality                      str
# Area_sqft                   int64
# Bedrooms                    int64
# Bathrooms                   int64
# Balconies                   int64
# Parking                       str
# Floor                       int64
# Total_Floors                int64
# Property_Age                int64
# Furnishing                    str
# Facing                        str
# Gated_Society                 str
# Lift                          str
# Power_Backup                  str
# Security                      str
# Gym                           str
# Swimming_Pool                 str
# Metro_Distance_km         float64
# Hospital_Distance_km      float64
# School_Distance_km        float64
# Mall_Distance_km          float64
# Expressway_Distance_km    float64
# RRTS_Distance_km          float64
# Price_INR                 float64
# dtype: object

# %%
df["Area_sqft"] = df["Area_sqft"].astype(float)

# %%
df["City"].unique()
# Out:
# <StringArray>
# ['Greater Noida', 'Delhi', 'Gurugram', 'Noida', 'Faridabad', 'Ghaziabad']
# Length: 6, dtype: str

# %%
df["Furnishing"].unique()
# Out:
# <StringArray>
# ['Semi-Furnished', 'Unfurnished', 'Fully Furnished']
# Length: 3, dtype: str

# %%
plt.boxplot(df["Price_INR"])
plt.show()

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Price_INR"], bins=30)

plt.title("Distribution of Property Prices")
plt.xlabel("Price (INR)")
plt.ylabel("Number of Properties")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.boxplot(df["Price_INR"])

plt.title("Box Plot of Property Prices")
plt.ylabel("Price (INR)")

plt.show()

# %%
city_counts = df["City"].value_counts()

plt.figure(figsize=(10,5))

plt.bar(city_counts.index, city_counts.values)

plt.title("Properties by City")
plt.xlabel("City")
plt.ylabel("Number of Properties")
plt.grid(True)

plt.xticks(rotation=45)

plt.show()

# %%
avg_price = df.groupby("City")["Price_INR"].mean()

plt.figure(figsize=(10,5))

plt.bar(avg_price.index, avg_price.values)

plt.title("Average Property Price by City")
plt.xlabel("City")
plt.ylabel("Average Price")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["Area_sqft"],
    df["Price_INR"],
    alpha=0.5
)

plt.title("Area vs Property Price")
plt.xlabel("Area (sqft)")
plt.ylabel("Price (INR)")

plt.show()

# %%
bedroom_price = df.groupby("Bedrooms")["Price_INR"].mean()

plt.figure(figsize=(8,5))

plt.plot(
    bedroom_price.index,
    bedroom_price.values,
    marker="o"
)

plt.title("Average Price by Number of Bedrooms")
plt.xlabel("Bedrooms")
plt.ylabel("Average Price")

plt.grid(True)

plt.show()

# %%
furnishing = df["Furnishing"].value_counts()

plt.figure(figsize=(8,5))

plt.bar(
    furnishing.index,
    furnishing.values
)

plt.title("Furnishing Status")
plt.xlabel("Furnishing")
plt.ylabel("Count")

plt.xticks(rotation=20)

plt.show()

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(10,6))

sns.histplot(df["Price_INR"], bins=30, kde=True)

plt.title("Distribution of Property Prices")
plt.xlabel("Price (INR)")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(y=df["Price_INR"])

plt.title("Box Plot of Property Prices")

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    data=df,
    x="City",
    order=df["City"].value_counts().index
)

plt.xticks(rotation=45)

plt.title("Number of Properties in Each City")

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df,
    x="City",
    y="Price_INR",
    estimator="mean"
)

plt.xticks(rotation=45)

plt.title("Average Property Price by City")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="Area_sqft",
    y="Price_INR"
)

plt.title("Area vs Price")

plt.show()

# %%
plt.figure(figsize=(12,8))

corr = df.select_dtypes(include=["int64","float64"]).corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="Bedrooms",
    y="Price_INR"
)

plt.title("Bedrooms vs Price")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.violinplot(
    data=df,
    x="Bedrooms",
    y="Price_INR"
)

plt.title("Bedrooms vs Price Distribution")

plt.show()

# %% [markdown]
# # Feature Engineering

# %%
X = df.drop("Price_INR", axis=1)
y = df["Price_INR"]

# %%
categorical_cols = X.select_dtypes(include="object").columns

numerical_cols = X.select_dtypes(exclude="object").columns

print("Categorical Columns:")
print(categorical_cols)

print("\nNumerical Columns:")
print(numerical_cols)
# Out:
# Categorical Columns:
# Index(['City', 'Locality', 'Parking', 'Furnishing', 'Facing', 'Gated_Society',
#        'Lift', 'Power_Backup', 'Security', 'Gym', 'Swimming_Pool'],
#       dtype='str')
#
# Numerical Columns:
# Index(['Area_sqft', 'Bedrooms', 'Bathrooms', 'Balconies', 'Floor',
#        'Total_Floors', 'Property_Age', 'Metro_Distance_km',
#        'Hospital_Distance_km', 'School_Distance_km', 'Mall_Distance_km',
#        'Expressway_Distance_km', 'RRTS_Distance_km'],
#       dtype='str')
# C:\Users\sk070\AppData\Local\Temp\ipykernel_3972\3750767116.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = X.select_dtypes(include="object").columns

# %% [markdown]
# ## One Hot Encoding (Textual Data Encoding)

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X.head()
# Out:
#    Area_sqft  Bedrooms  Bathrooms  Balconies  Floor  Total_Floors  \
# 0      552.0         3          2          1     23            24
# 1     3309.0         4          4          2      6            17
# 2      637.0         2          2          0      3            16
# 3     1349.0         3          2          1     25            28
# 4     2537.0         4          3          0      4            25
#
#    Property_Age  Metro_Distance_km  Hospital_Distance_km  School_Distance_km  \
# 0            21               2.87                  4.90                3.46
# 1             3               6.48                  7.79                2.40
# 2             8               8.45                  5.53                0.61
# 3            12               1.80                  1.29                4.52
# 4             5              11.66                  6.91                0.27
#
#    ...  Furnishing_Unfurnished  Facing_North  Facing_South  Facing_West  \
# 0  ...                   False         False          True        False
# 1  ...                    True         False         False         True
# 2  ...                   False         False         False        False
# 3  ...                    True         False         False         True
# 4  ...                   False         False         False        False
#
#    Gated_Society_Yes  Lift_Yes  Power_Backup_Yes  Security_Yes  Gym_Yes  \
# 0               True      True              True          True    False
# 1              False      True              True          True    False
# 2              False      True              True         False     True
# 3              False      True             False          True    False
# 4              False      True             False         False     True
#
#    Swimming_Pool_Yes
# 0               True
# 1              False
# 2              False
# 3               True
# 4              False
#
# [5 rows x 59 columns]

# %%
X.dtypes
# Out:
# Area_sqft                      float64
# Bedrooms                         int64
# Bathrooms                        int64
# Balconies                        int64
# Floor                            int64
# Total_Floors                     int64
# Property_Age                     int64
# Metro_Distance_km              float64
# Hospital_Distance_km           float64
# School_Distance_km             float64
# Mall_Distance_km               float64
# Expressway_Distance_km         float64
# RRTS_Distance_km               float64
# City_Faridabad                    bool
# City_Ghaziabad                    bool
# City_Greater Noida                bool
# City_Gurugram                     bool
# City_Noida                        bool
# Locality_Beta 2                   bool
# Locality_Crossings Republik       bool
# Locality_DLF Phase 1              bool
# Locality_DLF Phase 3              bool
# Locality_Dwarka                   bool
# Locality_Gamma 1                  bool
# Locality_Golf Course Road         bool
# Locality_Green Fields             bool
# Locality_Indirapuram              bool
# Locality_Janakpuri                bool
# Locality_Kaushambi                bool
# Locality_Knowledge Park           bool
# Locality_NIT                      bool
# Locality_Pari Chowk               bool
# Locality_Pitampura                bool
# Locality_Raj Nagar                bool
# Locality_Rohini                   bool
# Locality_Saket                    bool
# Locality_Sector 137               bool
# Locality_Sector 15                bool
# Locality_Sector 150               bool
# Locality_Sector 21                bool
# Locality_Sector 37                bool
# Locality_Sector 50                bool
# Locality_Sector 57                bool
# Locality_Sector 62                bool
# Locality_Sector 78                bool
# Locality_Sohna Road               bool
# Locality_Vaishali                 bool
# Parking_Yes                       bool
# Furnishing_Semi-Furnished         bool
# Furnishing_Unfurnished            bool
# Facing_North                      bool
# Facing_South                      bool
# Facing_West                       bool
# Gated_Society_Yes                 bool
# Lift_Yes                          bool
# Power_Backup_Yes                  bool
# Security_Yes                      bool
# Gym_Yes                           bool
# Swimming_Pool_Yes                 bool
# dtype: object

# %%
bool_cols = X.select_dtypes(include="bool").columns

X[bool_cols] = X[bool_cols].astype(int)

# %%
print(X.shape)
# Out:
# (29690, 59)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (23752, 59)
# (5938, 59)
# (23752,)
# (5938,)

# %% [markdown]
# # Building the Model

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
X_train.shape
# Out:
# (23752, 59)

# %%
X_test.shape
# Out:
# (5938, 59)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print(y_pred[:10])
# Out:
# [40008297.90105687 22710254.22004339 39198162.67704351  8757663.56983327
#  17232679.21594132 23875260.64489159 28244839.84160079 25780520.71014522
#   8477049.87051559  -667617.85308052]

# %%
r2 = r2_score(y_test, y_pred)

print("R² Score :", r2)
mse = mean_squared_error(y_test, y_pred)

print("MSE :", mse)
mae = mean_absolute_error(y_test, y_pred)

print("MAE :", mae)


rmse = np.sqrt(mse)

print("RMSE :", rmse)
# Out:
# R² Score : 0.8248553464079661
# MSE : 36766766021402.64
# MAE : 4747707.582393818
# RMSE : 6063560.506946611

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor(
    max_depth=10,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42
)

dt.fit(X_train, y_train)

dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae_dt = mean_absolute_error(y_test, y_pred_dt)
mse_dt = mean_squared_error(y_test, y_pred_dt)
rmse_dt = np.sqrt(mse_dt)
r2_dt = r2_score(y_test, y_pred_dt)

print("MAE :", mae_dt)
print("MSE :", mse_dt)
print("RMSE :", rmse_dt)
print("R² Score :", r2_dt)
# Out:
# MAE : 4086426.9764258787
# MSE : 30941171792566.883
# RMSE : 5562478.925134628
# R² Score : 0.8526065411304837

# %%
comparison_dt = pd.DataFrame({
    "Actual Price": y_test.values,
    "Predicted Price": y_pred_dt
})

comparison_dt.head(10)
# Out:
#    Actual Price  Predicted Price
# 0    50455656.0     3.968070e+07
# 1    18697845.0     2.262907e+07
# 2    26710539.0     3.308470e+07
# 3    12803795.0     1.209849e+07
# 4    12153563.0     1.720139e+07
# 5    20960407.0     1.616210e+07
# 6    35563151.0     2.631086e+07
# 7    21941886.0     2.262907e+07
# 8     6441222.0     8.487663e+06
# 9     5062279.0     4.411994e+06

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("MAE :", mae_rf)
print("MSE :", mse_rf)
print("RMSE :", rmse_rf)
print("R² Score :", r2_rf)
# Out:
# MAE : 3850781.7666849107
# MSE : 27359271376199.996
# RMSE : 5230609.082716849
# R² Score : 0.8696695242402995

# %% [markdown]
# ## Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=5,
    random_state=42
)

gbr.fit(X_train, y_train)

y_pred_gbr = gbr.predict(X_test)


mae_gbr = mean_absolute_error(y_test, y_pred_gbr)
mse_gbr = mean_squared_error(y_test, y_pred_gbr)
rmse_gbr = np.sqrt(mse_gbr)
r2_gbr = r2_score(y_test, y_pred_gbr)

print("MAE :", mae_gbr)
print("MSE :", mse_gbr)
print("RMSE :", rmse_gbr)
print("R² Score :", r2_gbr)
# Out:
# MAE : 3861478.50406512
# MSE : 27287203144691.574
# RMSE : 5223715.454031888
# R² Score : 0.8700128333427424

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
xgb = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="reg:squarederror",
    random_state=42
)

# %%
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

print("MAE :", mae_xgb)
print("MSE :", mse_xgb)
print("RMSE :", rmse_xgb)
print("R² Score :", r2_xgb)
# Out:
# MAE : 3852670.3087318963
# MSE : 27151408018776.574
# RMSE : 5210701.2981725
# R² Score : 0.870659716189986

# %%
print("Training R² :", xgb.score(X_train, y_train))
print("Testing R² :", xgb.score(X_test, y_test))
# Out:
# Training R² : 0.91956378227577
# Testing R² : 0.870659716189986

# %%
results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Decision Tree",
        "Random Forest",
        "Gradient Boosting",
        "XGBoost"
    ],
    "R2 Score": [
        r2,
        r2_dt,
        r2_rf,
        r2_gbr,
        r2_xgb
    ],
    "MAE": [
        mae,
        mae_dt,
        mae_rf,
        mae_gbr,
        mae_xgb
    ],
    "RMSE": [
        rmse,
        rmse_dt,
        rmse_rf,
        rmse_gbr,
        rmse_xgb
    ]
})

results.sort_values(by="R2 Score", ascending=False)
# Out:
#                Model  R2 Score           MAE          RMSE
# 4            XGBoost  0.870660  3.852670e+06  5.210701e+06
# 3  Gradient Boosting  0.870013  3.861479e+06  5.223715e+06
# 2      Random Forest  0.869670  3.850782e+06  5.230609e+06
# 1      Decision Tree  0.852607  4.086427e+06  5.562479e+06
# 0  Linear Regression  0.824855  4.747708e+06  6.063561e+06

# %% [markdown]
# ## Save the Model

# %%
import joblib

# %%
joblib.dump(xgb, "xgboost_model.pkl")
# Out:
# ['xgboost_model.pkl']

# %%
joblib.dump(X.columns.tolist(), "feature_columns.pkl")
# Out:
# ['feature_columns.pkl']

# %%
import os

print(os.getcwd())
# Out:
# F:\Property-Valuation-System\Notebook

# %%
df.to_csv("clean_property_data.csv", index=False)

# %%
print(df["Parking"].unique())
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
print(df["Furnishing"].unique())

print(df["Facing"].unique())

print(df["Gated_Society"].unique())

print(df["Lift"].unique())

print(df["Power_Backup"].unique())

print(df["Security"].unique())

print(df["Gym"].unique())

print(df["Swimming_Pool"].unique())
# Out:
# <StringArray>
# ['Semi-Furnished', 'Unfurnished', 'Fully Furnished']
# Length: 3, dtype: str
# <StringArray>
# ['South', 'West', 'East', 'North']
# Length: 4, dtype: str
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
print(feature_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 print(feature_columns)
#
# NameError: name 'feature_columns' is not defined

# %%
feature_columns = joblib.load("feature_columns.pkl")

print(feature_columns)
# Out:
# ['Area_sqft', 'Bedrooms', 'Bathrooms', 'Balconies', 'Floor', 'Total_Floors', 'Property_Age', 'Metro_Distance_km', 'Hospital_Distance_km', 'School_Distance_km', 'Mall_Distance_km', 'Expressway_Distance_km', 'RRTS_Distance_km', 'City_Faridabad', 'City_Ghaziabad', 'City_Greater Noida', 'City_Gurugram', 'City_Noida', 'Locality_Beta 2', 'Locality_Crossings Republik', 'Locality_DLF Phase 1', 'Locality_DLF Phase 3', 'Locality_Dwarka', 'Locality_Gamma 1', 'Locality_Golf Course Road', 'Locality_Green Fields', 'Locality_Indirapuram', 'Locality_Janakpuri', 'Locality_Kaushambi', 'Locality_Knowledge Park', 'Locality_NIT', 'Locality_Pari Chowk', 'Locality_Pitampura', 'Locality_Raj Nagar', 'Locality_Rohini', 'Locality_Saket', 'Locality_Sector 137', 'Locality_Sector 15', 'Locality_Sector 150', 'Locality_Sector 21', 'Locality_Sector 37', 'Locality_Sector 50', 'Locality_Sector 57', 'Locality_Sector 62', 'Locality_Sector 78', 'Locality_Sohna Road', 'Locality_Vaishali', 'Parking_Yes', 'Furnishing_Semi-Furnished', 'Furnishing_Unfurnished', 'Facing_North', 'Facing_South', 'Facing_West', 'Gated_Society_Yes', 'Lift_Yes', 'Power_Backup_Yes', 'Security_Yes', 'Gym_Yes', 'Swimming_Pool_Yes']
